# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
data={
    'EmployeeID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Department': ['Sales', 'HR', 'IT', 'Sales', 'HR', 'IT', 'Sales', 'HR', 'IT', 'Sales'],
    'YearsAtCompany': [5, 2, 7, 10, 1, 3, 4, 8, 2, 5],
    'PerformanceRating': [3, 4, 2, 5, 3, 5, 3, 4, 4, 3],
    'ActualPromotion': ['No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No'],
    'PredictedPromotion': ['No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No']
}
df=pd.DataFrame(data)
df
# Out:
#    EmployeeID Department  YearsAtCompany  PerformanceRating ActualPromotion  \
# 0         101      Sales               5                  3              No
# 1         102         HR               2                  4             Yes
# 2         103         IT               7                  2              No
# 3         104      Sales              10                  5             Yes
# 4         105         HR               1                  3              No
# 5         106         IT               3                  5             Yes
# 6         107      Sales               4                  3              No
# 7         108         HR               8                  4             Yes
# 8         109         IT               2                  4              No
# 9         110      Sales               5                  3              No
#
#   PredictedPromotion
# 0                 No
# 1                Yes
# 2                 No
# 3                Yes
# 4                 No
# 5                Yes
# 6                 No
# 7                 No
# 8                 No
# 9                 No

# %%
conf_matrix = confusion_matrix(df['ActualPromotion'],df['PredictedPromotion'],labels=['Yes','No'])
print(conf_matrix)
sns.set()
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=["Predicted: Yes", "Predicted: No"], yticklabels=["Actual: Yes", "Actual: No"])
plt.xlabel('Predicted Promotion')
plt.ylabel('Actual Promotion')
plt.title('Confusion matrix for Employee Promotion')
plt.show()
# Out:
# [[3 1]
#  [0 6]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
data = {
    'EmployeeID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Department': ['Sales', 'HR', 'IT', 'Sales', 'HR', 'IT', 'Sales', 'HR', 'IT', 'Sales'],
    'YearsAtCompany': [5, 2, 7, 10, 1, 3, 4, 8, 2, 5],
    'PerformanceRating': [3, 4, 2, 5, 3, 5, 3, 4, 4, 3],
    'ActualPromotion': ['No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No'],
    'PredictedPromotion': ['No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No']
}
df=pd.DataFrame(data)
df
# Out:
#    EmployeeID Department  YearsAtCompany  PerformanceRating ActualPromotion  \
# 0         101      Sales               5                  3              No
# 1         102         HR               2                  4             Yes
# 2         103         IT               7                  2              No
# 3         104      Sales              10                  5             Yes
# 4         105         HR               1                  3              No
# 5         106         IT               3                  5             Yes
# 6         107      Sales               4                  3              No
# 7         108         HR               8                  4             Yes
# 8         109         IT               2                  4              No
# 9         110      Sales               5                  3              No
#
#   PredictedPromotion
# 0                 No
# 1                Yes
# 2                 No
# 3                Yes
# 4                 No
# 5                Yes
# 6                 No
# 7                 No
# 8                 No
# 9                 No

# %%
conf_matrics=confusion_matrix(df['PredictedPromotion'],df['ActualPromotion'],labels=['Yes','No'])
print(conf_matrics)
plt.figure(figsize=(10,6))
sns.heatmap(conf_matrics,annot=True,fmt='d',color='Red',xticklabels=["Prediction: Yes","Prediction: No"],yticklabels=["Actual:Yes","Actual:No"])
plt.xlabel("prediction for promotion")
plt.ylabel('Actual promotion')
plt.title("Confusion matrix for Promotion Prediction")
plt.show()
# Out:
# [[3 0]
#  [1 6]]
